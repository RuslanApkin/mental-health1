# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import joblib

# %%
X_train = pd.read_csv('../dataset_processed/X_train.csv')
y_train = pd.read_csv('../dataset_processed/y_train.csv')
X_test = pd.read_csv('../dataset_processed/X_test.csv')
y_test = pd.read_csv('../dataset_processed/y_test.csv')

# %%
# Убедимся, что y_train и y_test являются одномерными массивами
y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# %%
# Обучение модели логистической регрессии
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Предсказание вероятностей
y_pred_proba = clf.predict_proba(X_test)[:, 1]  # вероятность класса "1" (т.е. 2, если 0 и 2)

# %%
# Предсказания меток (если нужны)
y_pred = clf.predict(X_test)

# %%
# Оценка точности модели
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.7131474103585658

# %%
# Детальный отчет по классификации
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.78      0.73       124
#            2       0.75      0.65      0.69       127
#
#     accuracy                           0.71       251
#    macro avg       0.72      0.71      0.71       251
# weighted avg       0.72      0.71      0.71       251

# %%
# Пример вероятностей
for pred, prob in zip(y_pred, y_pred_proba):
    print(f'Predicted class: {pred}, Probability: {prob}')
# Out:
# Predicted class: 2, Probability: 0.9347239974454182
# Predicted class: 0, Probability: 0.14530532360503307
# Predicted class: 0, Probability: 0.20203005202038504
# Predicted class: 2, Probability: 0.5731296584661567
# Predicted class: 2, Probability: 0.8788054840155635
# Predicted class: 0, Probability: 0.4614297001481638
# Predicted class: 0, Probability: 0.20350344175393578
# Predicted class: 2, Probability: 0.554643195834291
# Predicted class: 2, Probability: 0.5185460511542511
# Predicted class: 2, Probability: 0.6743115756180211
# Predicted class: 0, Probability: 0.4944317765306792
# Predicted class: 2, Probability: 0.7260398842191708
# Predicted class: 2, Probability: 0.7924265271172732
# Predicted class: 2, Probability: 0.8412965175372321
# Predicted class: 2, Probability: 0.6866873185603827
# Predicted class: 0, Probability: 0.23526048350987167
# Predicted class: 0, Probability: 0.4540105115505859
# Predicted class: 2, Probability: 0.6263425214445075
# Predicted class: 0, Probability: 0.24108959222334259
# Predicted class: 0, Probability: 0.25868280955082257
# Predicted class: 0, Probability: 0.3596841817606056
# Predicted class: 0, Probability: 0.4832828448750975
# Predicted class: 0, Probability: 0.33122042333576857
# Predicted class: 0, Probability: 0.3301986193385872
# Predicted class: 0, Probability: 0.31991704120115305
# Predicted class: 0, Probability: 0.13256864364578586
# Predicted class: 2, Probability: 0.8530444462931359
# Predicted class: 0, Probability: 0.3005363507853369
# Predicted class: 0, Probability: 0.43497031222222116
# Predicted class: 0, Probability: 0.44077538233833524
# Predicted class: 0, Probability: 0.4289207969724737
# Predicted class: 0, Probability: 0.3014663218425282
# Predicted class: 0, Probability: 0.18826183748265685
# Predicted class: 0, Probability: 0.32228183838351293
# Predicted class: 2, Probability: 0.652351816248205
# Predicted class: 0, Probability: 0.2608991566990303
# Predicted class: 0, Probability: 0.4380785009548616
# Predicted class: 2, Probability: 0.7977539074659582
# Predicted class: 0, Probability: 0.40874973399651765
# Predicted class: 0, Probability: 0.24598520018376507
# Predicted class: 2, Probability: 0.7164433062511739
# Predicted class: 2, Probability: 0.9039577455680695
# Predicted class: 0, Probability: 0.14287841102022944
# Predicted class: 0, Probability: 0.3069786303486732
# Predicted class: 0, Probability: 0.33293539674857137
# Predicted class: 2, Probability: 0.6205282196818228
# Predicted class: 2, Probability: 0.5149749140351204
# Predicted class: 0, Probability: 0.4926696710479641
# Predicted class: 0, Probability: 0.3553053311645053
# Predicted class: 0, Probability: 0.2093783630962721
# Predicted class: 0, Probability: 0.3385165637433645
# Predicted class: 0, Probability: 0.2617446989956098
# Predicted class: 0, Probability: 0.2787758453090104
# Predicted class: 0, Probability: 0.30125059256332337
# Predicted class: 0, Probability: 0.38532937068652584
# Predicted class: 0, Probability: 0.3416465926717707
# Predicted class: 2, Probability: 0.7649244088486219
# Predicted class: 2, Probability: 0.535488599541351
# Predicted class: 2, Probability: 0.6506841231810979
# Predicted class: 0, Probability: 0.46177908417312885
# Predicted class: 2, Probability: 0.7330619222638308
# Predicted class: 2, Probability: 0.7963269465904707
# Predicted class: 0, Probability: 0.33424776231385667
# Predicted class: 2, Probability: 0.8467417137478463
# Predicted class: 2, Probability: 0.6714126946123667
# Predicted class: 0, Probability: 0.3400148213363329
# Predicted class: 0, Probability: 0.21775484634650147
# Predicted class: 0, Probability: 0.4413259026456445
# Predicted class: 2, Probability: 0.6476411677003449
# Predicted class: 0, Probability: 0.3733352447317117
# Predicted class: 0, Probability: 0.40097488086088867
# Predicted class: 0, Probability: 0.28455456537544027
# Predicted class: 2, Probability: 0.7940552812970978
# Predicted class: 0, Probability: 0.32744053186005384
# Predicted class: 0, Probability: 0.38003749495679506
# Predicted class: 2, Probability: 0.6881669731591059
# Predicted class: 2, Probability: 0.8167490574168059
# Predicted class: 2, Probability: 0.7482604015430344
# Predicted class: 0, Probability: 0.34724095540485567
# Predicted class: 0, Probability: 0.2875027088530807
# Predicted class: 2, Probability: 0.5710237669705351
# Predicted class: 0, Probability: 0.2420672825620597
# Predicted class: 0, Probability: 0.14442353946333314
# Predicted class: 2, Probability: 0.684389600574328
# Predicted class: 2, Probability: 0.7294835010068972
# Predicted class: 2, Probability: 0.6848428265575686
# Predicted class: 2, Probability: 0.7282903392750922
# Predicted class: 0, Probability: 0.2654756849344396
# Predicted class: 2, Probability: 0.5860196312422488
# Predicted class: 2, Probability: 0.7713336739211151
# Predicted class: 0, Probability: 0.3111851062771511
# Predicted class: 0, Probability: 0.38335368524224056
# Predicted class: 0, Probability: 0.31656372365214086
# Predicted class: 2, Probability: 0.6780220758583918
# Predicted class: 2, Probability: 0.6071488086313612
# Predicted class: 0, Probability: 0.3905505368614886
# Predicted class: 2, Probability: 0.8002528000304165
# Predicted class: 0, Probability: 0.2711171269506673
# Predicted class: 0, Probability: 0.3267396727886484
# Predicted class: 2, Probability: 0.7206026548540572
# Predicted class: 0, Probability: 0.28107641566644215
# Predicted class: 2, Probability: 0.7290564860421248
# Predicted class: 2, Probability: 0.5872917967213834
# Predicted class: 0, Probability: 0.2967547728037681
# Predicted class: 2, Probability: 0.8730537181178122
# Predicted class: 0, Probability: 0.4890584302143132
# Predicted class: 0, Probability: 0.4081135361461088
# Predicted class: 0, Probability: 0.26261489355939194
# Predicted class: 0, Probability: 0.19218848971451308
# Predicted class: 0, Probability: 0.4457294066932284
# Predicted class: 2, Probability: 0.7260622968703871
# Predicted class: 0, Probability: 0.48876928243761536
# Predicted class: 0, Probability: 0.48789179810276967
# Predicted class: 2, Probability: 0.7001772798570364
# Predicted class: 2, Probability: 0.9153132221432599
# Predicted class: 0, Probability: 0.48337704625703665
# Predicted class: 0, Probability: 0.4866907612284706
# Predicted class: 2, Probability: 0.6661502421626462
# Predicted class: 0, Probability: 0.37413167030707206
# Predicted class: 2, Probability: 0.8775109491908489
# Predicted class: 2, Probability: 0.9509225067382472
# Predicted class: 0, Probability: 0.35166759205981996
# Predicted class: 0, Probability: 0.42970001477639036
# Predicted class: 2, Probability: 0.5814450075944494
# Predicted class: 0, Probability: 0.4987064892400086
# Predicted class: 2, Probability: 0.8407249204980963
# Predicted class: 2, Probability: 0.9505744736729547
# Predicted class: 2, Probability: 0.6712040199186087
# Predicted class: 2, Probability: 0.5551785720382356
# Predicted class: 0, Probability: 0.2883323398493755
# Predicted class: 0, Probability: 0.38777150527474885
# Predicted class: 2, Probability: 0.7705190686150991
# Predicted class: 0, Probability: 0.2584909375004394
# Predicted class: 0, Probability: 0.20609956897525283
# Predicted class: 0, Probability: 0.4060767151393274
# Predicted class: 0, Probability: 0.44469555000779326
# Predicted class: 0, Probability: 0.466077306810305
# Predicted class: 0, Probability: 0.13918170493300316
# Predicted class: 0, Probability: 0.15943112811132767
# Predicted class: 2, Probability: 0.792476350974297
# Predicted class: 2, Probability: 0.609740640766954
# Predicted class: 0, Probability: 0.223599641864741
# Predicted class: 2, Probability: 0.823643081347336
# Predicted class: 0, Probability: 0.34857188430679387
# Predicted class: 0, Probability: 0.26979359911902895
# Predicted class: 2, Probability: 0.5996196417352491
# Predicted class: 0, Probability: 0.26079121563542096
# Predicted class: 0, Probability: 0.31485681936762755
# Predicted class: 0, Probability: 0.3659225300822823
# Predicted class: 0, Probability: 0.3695413038345079
# Predicted class: 2, Probability: 0.6023641499509406
# Predicted class: 0, Probability: 0.13852265124126703
# Predicted class: 2, Probability: 0.7448705728312546
# Predicted class: 2, Probability: 0.6816667714146604
# Predicted class: 0, Probability: 0.4097739750282888
# Predicted class: 2, Probability: 0.861295095361024
# Predicted class: 2, Probability: 0.7869743917832297
# Predicted class: 2, Probability: 0.7777327180631355
# Predicted class: 2, Probability: 0.6963493100376014
# Predicted class: 0, Probability: 0.45841265355336164
# Predicted class: 2, Probability: 0.6576157945989789
# Predicted class: 2, Probability: 0.5533575027075015
# Predicted class: 2, Probability: 0.7611098608854716
# Predicted class: 2, Probability: 0.6560878596449469
# Predicted class: 2, Probability: 0.811772836339869
# Predicted class: 0, Probability: 0.30886811665951913
# Predicted class: 2, Probability: 0.6149202053882616
# Predicted class: 0, Probability: 0.3401329735799673
# Predicted class: 0, Probability: 0.43420252172533735
# Predicted class: 2, Probability: 0.7733412045284956
# Predicted class: 2, Probability: 0.8173124032050056
# Predicted class: 2, Probability: 0.6766514301912394
# Predicted class: 0, Probability: 0.22629610528671218
# Predicted class: 2, Probability: 0.8676692294566634
# Predicted class: 0, Probability: 0.16658994857578777
# Predicted class: 2, Probability: 0.6831485508968499
# Predicted class: 0, Probability: 0.4342895071722609
# Predicted class: 2, Probability: 0.6704374296200625
# Predicted class: 2, Probability: 0.6030514653194595
# Predicted class: 0, Probability: 0.34572617690693586
# Predicted class: 2, Probability: 0.6665095409284066
# Predicted class: 2, Probability: 0.7689346483868644
# Predicted class: 0, Probability: 0.2479121702079867
# Predicted class: 2, Probability: 0.5879122933757719
# Predicted class: 2, Probability: 0.7550819196948643
# Predicted class: 0, Probability: 0.27350927714339396
# Predicted class: 0, Probability: 0.4771862825973593
# Predicted class: 0, Probability: 0.23267026341317212
# Predicted class: 0, Probability: 0.22680369408005197
# Predicted class: 0, Probability: 0.41967535758694496
# Predicted class: 0, Probability: 0.34389327939410347
# Predicted class: 0, Probability: 0.40085672483173024
# Predicted class: 0, Probability: 0.4591483232363477
# Predicted class: 2, Probability: 0.7197347672621223
# Predicted class: 0, Probability: 0.267781460992331
# Predicted class: 0, Probability: 0.4758071230773852
# Predicted class: 2, Probability: 0.7391067528128963
# Predicted class: 2, Probability: 0.6340049193485257
# Predicted class: 0, Probability: 0.47606481673873713
# Predicted class: 0, Probability: 0.34052167554504803
# Predicted class: 0, Probability: 0.2977305052869411
# Predicted class: 0, Probability: 0.09454531016144317
# Predicted class: 0, Probability: 0.24563153158514173
# Predicted class: 2, Probability: 0.8332372233007542
# Predicted class: 2, Probability: 0.7027472309453947
# Predicted class: 0, Probability: 0.19549633688498777
# Predicted class: 2, Probability: 0.8640091576799555
# Predicted class: 0, Probability: 0.22718048286194964
# Predicted class: 2, Probability: 0.8841539511169818
# Predicted class: 2, Probability: 0.8689293884763087
# Predicted class: 0, Probability: 0.25465678737338515
# Predicted class: 0, Probability: 0.32220309728810576
# Predicted class: 2, Probability: 0.6906479934035128
# Predicted class: 2, Probability: 0.6933304504839477
# Predicted class: 0, Probability: 0.14787726402023926
# Predicted class: 2, Probability: 0.71037953940808
# Predicted class: 2, Probability: 0.8132883676847324
# Predicted class: 2, Probability: 0.8956484508334652
# Predicted class: 0, Probability: 0.3532440689188092
# Predicted class: 2, Probability: 0.6503625993554188
# Predicted class: 0, Probability: 0.3306999287411257
# Predicted class: 0, Probability: 0.3526144813352447
# Predicted class: 0, Probability: 0.28701034289158034
# Predicted class: 2, Probability: 0.5127042515059734
# Predicted class: 2, Probability: 0.8101368948532846
# Predicted class: 0, Probability: 0.3257183645772011
# Predicted class: 0, Probability: 0.44558701705142423
# Predicted class: 0, Probability: 0.3031817455782742
# Predicted class: 0, Probability: 0.48458754079306193
# Predicted class: 0, Probability: 0.4559838191132534
# Predicted class: 2, Probability: 0.7454641873409751
# Predicted class: 2, Probability: 0.5237494499678703
# Predicted class: 2, Probability: 0.8281970328696047
# Predicted class: 2, Probability: 0.8130023342410587
# Predicted class: 0, Probability: 0.3107573625796151
# Predicted class: 0, Probability: 0.24779955612349858
# Predicted class: 2, Probability: 0.8213910651896578
# Predicted class: 0, Probability: 0.40248192655014126
# Predicted class: 0, Probability: 0.27580184363819227
# Predicted class: 2, Probability: 0.7297502229746387
# Predicted class: 2, Probability: 0.6848218657961661
# Predicted class: 0, Probability: 0.22765431442530132
# Predicted class: 0, Probability: 0.36119216040271607
# Predicted class: 0, Probability: 0.25576505588668674
# Predicted class: 0, Probability: 0.34153400254173194
# Predicted class: 2, Probability: 0.7401762133880869
# Predicted class: 0, Probability: 0.21683019628844405
# Predicted class: 0, Probability: 0.24375966553846834
# Predicted class: 2, Probability: 0.5184826568615889
# Predicted class: 0, Probability: 0.4148786745581747
# Predicted class: 0, Probability: 0.4604826589292066

# %%
# Сохранение модели в файл
joblib.dump(clf, '../model/model.pkl')
# Out:
# ['../model/model.pkl']
